# %% [markdown]
# # SemEval 2026 Task 4: Baseline Pipeline
#
# This notebook runs the baseline pipeline for Track A (Narrative Similarity).
#
# ## Setup
# 1. Upload the `semeval-2026-task-4-baselines-main` folder to your Google Drive.
# 2. Mount Google Drive below.
# 3. Navigate to the folder.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
# CHANGE THIS PATH to where you uploaded the folder
os.chdir('/content/drive/MyDrive/semeval-2026-task-4-baselines-main')
print(os.getcwd())

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Training Baseline B (LSTM)

# %%
# !python train.py --model B --epochs 5 --batch_size 8

# %% [markdown]
# ## Training Baseline C (BERT)

# %%
# !python train.py --model C --epochs 3 --batch_size 4

# %% [markdown]
# ## Evaluation
#
# ### Baseline A (GPT-4o)
# Note: Requires `OPENAI_API_KEY` environment variable.

# %%
import os
from getpass import getpass
os.environ['OPENAI_API_KEY'] = getpass('Enter OpenAI API Key: ')

# %%
# !python evaluate.py --model A

# %% [markdown]
# ### Baseline B (LSTM)

# %%
# !python evaluate.py --model B --checkpoint output/model_B_epoch_5.pt

# %% [markdown]
# ### Baseline C (BERT)

# %%
# !python evaluate.py --model C --checkpoint output/model_C_epoch_3.pt

# %% [markdown]
# ## View Results

# %%
import json
import matplotlib.pyplot as plt
from IPython.display import IFrame

# Display metrics
if os.path.exists('results/metrics.json'):
    with open('results/metrics.json', 'r') as f:
        print(json.load(f))

# Note: PDF plots are saved in results/plots/. You can view them in the file browser.
